# %% [markdown]
# # Business Intelligence ETL Using Pandas
#
# ### By Welemhret Welay Baraki

# %% [markdown]
# ### Import the necessary python packages

# %%
#Import the necessary Python Libraries 
import pandas as pd 
import numpy as np

# %% [markdown]
# ### Import the dataset for the years 1989 and 1999

# %%
#Import the datasets of Flight information for the Years 1989 and 1999
Data1989=pd.read_csv("BI datasets/1989.csv")
Data1999=pd.read_csv("BI datasets/1999.csv")
#Import the US Airtports dataset to extract the states that the airport belongs
UsAirpots=pd.read_csv("BI datasets/us-airports.csv")
#Importing WorldAirports
WorldAirPorts=pd.read_csv("BI datasets/airports_iata_codes.csv")

# %%
#Explore the size of the datasets
Data1989.shape, Data1999.shape,UsAirpots.shape,WorldAirPorts.shape
# Out:
# ((5041200, 29), (5527884, 29), (29008, 23), (8738, 8))

# %% [markdown]
# ### Adding Airport Names based on the IATA Code from Airports IATA codes Datasets

# %%
#Selecting the Airport IATA Code and their Corresponding Local Names
WorldAirPorts=WorldAirPorts[["iata_code","name"]]
#Change the column names to ["Origin","AirPortName"]
WorldAirPorts.columns=["Origin","AirPortName"]

# %% [markdown]
# ### Adding Airport Name based on the Origin column

# %%
Data1989=pd.merge(Data1989,WorldAirPorts,on=['Origin'], how='left')
Data1999=pd.merge(Data1999,WorldAirPorts,on=['Origin'], how='left')

# %%
Data1999.tail()
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 5527879  1999     12          16          4   1910.0        1910   2112.0
# 5527880  1999     12          17          5   1909.0        1910   2111.0
# 5527881  1999     12          18          6   1907.0        1910   2103.0
# 5527882  1999     12          19          7   1907.0        1910   2114.0
# 5527883  1999     12          20          1   1905.0        1910   2127.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiOut  Cancelled  \
# 5527879        2117            AA       1359  ...      12          0
# 5527880        2117            AA       1359  ...      15          0
# 5527881        2117            AA       1359  ...       9          0
# 5527882        2117            AA       1359  ...      13          0
# 5527883        2117            AA       1359  ...       8          0
#
#          CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# 5527879               NaN         0           NaN           NaN      NaN
# 5527880               NaN         0           NaN           NaN      NaN
# 5527881               NaN         0           NaN           NaN      NaN
# 5527882               NaN         0           NaN           NaN      NaN
# 5527883               NaN         0           NaN           NaN      NaN
#
#         SecurityDelay  LateAircraftDelay                      AirPortName
# 5527879           NaN                NaN  Nashville International Airport
# 5527880           NaN                NaN  Nashville International Airport
# 5527881           NaN                NaN  Nashville International Airport
# 5527882           NaN                NaN  Nashville International Airport
# 5527883           NaN                NaN  Nashville International Airport
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Adding AirPort State/Region in the US based on the IATA Code from the UsAirpots Datasets

# %%
#Extract the IATA code of the Airports and States/Region Name/ location of the Airport
#Reset index and drop duplicates to filter list of airports and their regions
AirportRegion=UsAirpots[["iata_code","region_name"]].reset_index(drop=True).drop_duplicates(subset=["iata_code","region_name"], keep='last')

# %%
#Drop Null Values 
AirportRegion=AirportRegion.dropna()

# %%
# Rename the iata_code column of the dataframe with "Origin" 
# to be able to merge with the datasets of 1989 and 1999
AirportRegion.rename(columns={"iata_code":"Origin"},inplace=True)

# %%
#Airport Region Columns
#Add the missing region names for the following airports
MisseDetails={
    "Origin":['PFN', 'STT', 'STX', 'UCA', 'SJU', 'GUM', 'YAP', 'SPN','ROP'],
    "region_name":['Florida','US Virgin Islands','US Virgin Islands','New York',
                   'Puerto Rico','Guam','Yap Islands','Mariana Islands','Mariana Islands']}
Missed=pd.DataFrame(MisseDetails)
Missed
AirportRegion=pd.concat([AirportRegion, Missed])

# %%
#Add the States based on the Origin Airport to the data of the year 1989
Data1989=pd.merge(Data1989,AirportRegion,on=['Origin'], how='left')
#Add the States based on the Origin Airport to the data of 1999
Data1999=pd.merge(Data1999,AirportRegion,on=['Origin'], how='left')

# %%
# Check if the there are null values in the region name in 1999
Data1989[Data1989["region_name"].isna() ]["Origin"].unique()
# Check if the there are null values in the region name in 1999
Data1999[Data1999["region_name"].isna() ]["Origin"].unique()
# Out:
# array([], dtype=object)

# %% [markdown]
# ### Adding the Air Line Name based on the Unique Carrier IATA Codes

# %%
# List the 13 Unique Carriers /Air Lines/ 
Data1989['UniqueCarrier'].unique()
# Out:
# array(['UA', 'US', 'WN', 'NW', 'PA (1)', 'PI', 'TW', 'DL', 'EA', 'HP',
#        'AA', 'AS', 'CO'], dtype=object)

# %%
Data1999['UniqueCarrier'].unique()
# Out:
# array(['US', 'UA', 'AA', 'DL', 'TW', 'HP', 'WN', 'CO', 'NW', 'AS'],
#       dtype=object)

# %%
USAirlines={
    "UniqueCarrier":['UA', 'US', 'WN', 'NW', 'PA', 'PI', 'TW', 'DL', 'EA', 'HP', 'AA', 'AS', 'CO'],
    "AirLines":["United Air Lines Inc.","US Airways Inc.","Southwest Airlines Co.","Northwest Airlines Inc.",
               "Florida Coastal Airlines","Piedmont Aviation Inc.","Trans World Airways LLC", "Delta Air Lines Inc.",
               "Eastern Air Lines Inc.","America West Airlines Inc.","American Airlines Inc.",
               "Alaska Airlines Inc.","Continental Air Lines Inc."
               
              ]}
USAirlines=pd.DataFrame(USAirlines)
USAirlines
# Out:
#    UniqueCarrier                    AirLines
# 0             UA       United Air Lines Inc.
# 1             US             US Airways Inc.
# 2             WN      Southwest Airlines Co.
# 3             NW     Northwest Airlines Inc.
# 4             PA    Florida Coastal Airlines
# 5             PI      Piedmont Aviation Inc.
# 6             TW     Trans World Airways LLC
# 7             DL        Delta Air Lines Inc.
# 8             EA      Eastern Air Lines Inc.
# 9             HP  America West Airlines Inc.
# 10            AA      American Airlines Inc.
# 11            AS        Alaska Airlines Inc.
# 12            CO  Continental Air Lines Inc.

# %%
# Add AirLines column that identifies The Unique Carriers code with Human readable and easily understandable
Data1989=pd.merge(Data1989,USAirlines,on=['UniqueCarrier'], how='left')
Data1999=pd.merge(Data1999,USAirlines,on=['UniqueCarrier'], how='left')

# %%
Data1999
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0        1999      1          27          3   1906.0        1908   2024.0
# 1        1999      1          28          4   2016.0        1908   2126.0
# 2        1999      1          29          5   1907.0        1908   2000.0
# 3        1999      1          31          7   1932.0        1908   2031.0
# 4        1999      1           1          5   1601.0        1535   1707.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 5527879  1999     12          16          4   1910.0        1910   2112.0
# 5527880  1999     12          17          5   1909.0        1910   2111.0
# 5527881  1999     12          18          6   1907.0        1910   2103.0
# 5527882  1999     12          19          7   1907.0        1910   2114.0
# 5527883  1999     12          20          1   1905.0        1910   2127.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... CancellationCode  Diverted  \
# 0              2005            US       1244  ...              NaN         0
# 1              2005            US       1244  ...              NaN         0
# 2              2005            US       1244  ...              NaN         0
# 3              2005            US       1244  ...              NaN         0
# 4              1645            US        297  ...              NaN         0
# ...             ...           ...        ...  ...              ...       ...
# 5527879        2117            AA       1359  ...              NaN         0
# 5527880        2117            AA       1359  ...              NaN         0
# 5527881        2117            AA       1359  ...              NaN         0
# 5527882        2117            AA       1359  ...              NaN         0
# 5527883        2117            AA       1359  ...              NaN         0
#
#          CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  \
# 0                 NaN           NaN       NaN            NaN
# 1                 NaN           NaN       NaN            NaN
# 2                 NaN           NaN       NaN            NaN
# 3                 NaN           NaN       NaN            NaN
# 4                 NaN           NaN       NaN            NaN
# ...               ...           ...       ...            ...
# 5527879           NaN           NaN       NaN            NaN
# 5527880           NaN           NaN       NaN            NaN
# 5527881           NaN           NaN       NaN            NaN
# 5527882           NaN           NaN       NaN            NaN
# 5527883           NaN           NaN       NaN            NaN
#
#         LateAircraftDelay                              AirPortName  \
# 0                     NaN           Richmond International Airport
# 1                     NaN           Richmond International Airport
# 2                     NaN           Richmond International Airport
# 3                     NaN           Richmond International Airport
# 4                     NaN  Greater Rochester International Airport
# ...                   ...                                      ...
# 5527879               NaN          Nashville International Airport
# 5527880               NaN          Nashville International Airport
# 5527881               NaN          Nashville International Airport
# 5527882               NaN          Nashville International Airport
# 5527883               NaN          Nashville International Airport
#
#          region_name                AirLines
# 0           Virginia         US Airways Inc.
# 1           Virginia         US Airways Inc.
# 2           Virginia         US Airways Inc.
# 3           Virginia         US Airways Inc.
# 4           New York         US Airways Inc.
# ...              ...                     ...
# 5527879    Tennessee  American Airlines Inc.
# 5527880    Tennessee  American Airlines Inc.
# 5527881    Tennessee  American Airlines Inc.
# 5527882    Tennessee  American Airlines Inc.
# 5527883    Tennessee  American Airlines Inc.
#
# [5527884 rows x 32 columns]

# %% [markdown]
# ### Exploring the data of the Years 1989 and 1999

# %%
#Descriptive Statistics of the year 1989
Data1989.describe().T
# Out:
#                        count         mean         std     min     25%     50%  \
# Year               5041200.0  1989.000000    0.000000  1989.0  1989.0  1989.0
# Month              5041200.0     6.518804    3.469415     1.0     3.0     7.0
# DayofMonth         5041200.0    15.708359    8.781560     1.0     8.0    16.0
# DayOfWeek          5041200.0     3.956539    1.993352     1.0     2.0     4.0
# DepTime            4967035.0  1364.867275  478.128976     1.0   943.0  1341.0
# CRSDepTime         5041200.0  1356.045163  471.424060     1.0   935.0  1335.0
# ArrTime            4952196.0  1497.377673  497.331375     1.0  1119.0  1523.0
# CRSArrTime         5041200.0  1496.717477  485.221218     1.0  1118.0  1521.0
# FlightNum          5041200.0   773.888815  582.273113     1.0   325.0   640.0
# TailNum                  0.0          NaN         NaN     NaN     NaN     NaN
# ActualElapsedTime  4952196.0   107.475596   63.653940  -591.0    63.0    88.0
# CRSElapsedTime     5041200.0   107.036025   63.236711   -60.0    63.0    87.0
# AirTime                  0.0          NaN         NaN     NaN     NaN     NaN
# ArrDelay           4952196.0     8.406396   25.229399 -1263.0    -4.0     3.0
# DepDelay           4967035.0     8.202822   23.595179  -662.0     0.0     0.0
# Distance           5014212.0   618.291759  513.462078     0.0   258.0   446.0
# TaxiIn                   0.0          NaN         NaN     NaN     NaN     NaN
# TaxiOut                  0.0          NaN         NaN     NaN     NaN     NaN
# Cancelled          5041200.0     0.014712    0.120397     0.0     0.0     0.0
# CancellationCode         0.0          NaN         NaN     NaN     NaN     NaN
# Diverted           5041200.0     0.002944    0.054175     0.0     0.0     0.0
# CarrierDelay             0.0          NaN         NaN     NaN     NaN     NaN
# WeatherDelay             0.0          NaN         NaN     NaN     NaN     NaN
# NASDelay                 0.0          NaN         NaN     NaN     NaN     NaN
# SecurityDelay            0.0          NaN         NaN     NaN     NaN     NaN
# LateAircraftDelay        0.0          NaN         NaN     NaN     NaN     NaN
#
#                       75%     max
# Year               1989.0  1989.0
# Month                10.0    12.0
# DayofMonth           23.0    31.0
# DayOfWeek             6.0     7.0
# DepTime            1750.0  2400.0
# CRSDepTime         1743.0  2400.0
# ArrTime            1921.0  2400.0
# CRSArrTime         1916.0  2400.0
# FlightNum          1103.0  9368.0
# TailNum               NaN     NaN
# ActualElapsedTime   136.0  1494.0
# CRSElapsedTime      135.0  1555.0
# AirTime               NaN     NaN
# ArrDelay             13.0  1356.0
# DepDelay              8.0  1646.0
# Distance            839.0  4502.0
# TaxiIn                NaN     NaN
# TaxiOut               NaN     NaN
# Cancelled             0.0     1.0
# CancellationCode      NaN     NaN
# Diverted              0.0     1.0
# CarrierDelay          NaN     NaN
# WeatherDelay          NaN     NaN
# NASDelay              NaN     NaN
# SecurityDelay         NaN     NaN
# LateAircraftDelay     NaN     NaN

# %%
#Descriptive Statistics of the year 1999
Data1999.describe().T
# Out:
#                        count         mean         std     min     25%     50%  \
# Year               5527884.0  1999.000000    0.000000  1999.0  1999.0  1999.0
# Month              5527884.0     6.564378    3.434520     1.0     4.0     7.0
# DayofMonth         5527884.0    15.706164    8.776228     1.0     8.0    16.0
# DayOfWeek          5527884.0     3.935001    1.986862     1.0     2.0     4.0
# DepTime            5373573.0  1354.402954  488.349982     1.0   930.0  1338.0
# CRSDepTime         5527884.0  1292.790574  538.616370     0.0   900.0  1315.0
# ArrTime            5360018.0  1490.694977  518.304143     1.0  1110.0  1523.0
# CRSArrTime         5527884.0  1437.879420  571.806206     0.0  1049.0  1502.0
# FlightNum          5527884.0  1089.734731  748.170985     1.0   463.0   982.0
# ActualElapsedTime  5360018.0   126.505774   69.920844  -344.0    74.0   108.0
# CRSElapsedTime     5518892.0   127.326386   69.543824   -54.0    75.0   110.0
# AirTime            5360018.0   104.704728   66.207416     1.0    55.0    86.0
# ArrDelay           5360018.0     8.246601   33.007605  -194.0    -7.0     0.0
# DepDelay           5373573.0     9.337101   32.268676   -85.0    -2.0     0.0
# Distance           5527884.0   753.215399  563.079517    16.0   334.0   595.0
# TaxiIn             5527884.0     5.907943    4.525955     0.0     3.0     5.0
# TaxiOut            5527884.0    15.280217   11.089781     0.0    10.0    13.0
# Cancelled          5527884.0     0.027915    0.164729     0.0     0.0     0.0
# CancellationCode         0.0          NaN         NaN     NaN     NaN     NaN
# Diverted           5527884.0     0.002452    0.049458     0.0     0.0     0.0
# CarrierDelay             0.0          NaN         NaN     NaN     NaN     NaN
# WeatherDelay             0.0          NaN         NaN     NaN     NaN     NaN
# NASDelay                 0.0          NaN         NaN     NaN     NaN     NaN
# SecurityDelay            0.0          NaN         NaN     NaN     NaN     NaN
# LateAircraftDelay        0.0          NaN         NaN     NaN     NaN     NaN
#
#                       75%     max
# Year               1999.0  1999.0
# Month                10.0    12.0
# DayofMonth           23.0    31.0
# DayOfWeek             6.0     7.0
# DepTime            1746.0  2400.0
# CRSDepTime         1729.0  2400.0
# ArrTime            1925.0  2400.0
# CRSArrTime         1913.0  2400.0
# FlightNum          1648.0  6537.0
# ActualElapsedTime   159.0  1771.0
# CRSElapsedTime      159.0  1530.0
# AirTime             135.0  1082.0
# ArrDelay             12.0  1724.0
# DepDelay              7.0  1740.0
# Distance            987.0  4962.0
# TaxiIn                7.0   504.0
# TaxiOut              18.0   459.0
# Cancelled             0.0     1.0
# CancellationCode      NaN     NaN
# Diverted              0.0     1.0
# CarrierDelay          NaN     NaN
# WeatherDelay          NaN     NaN
# NASDelay              NaN     NaN
# SecurityDelay         NaN     NaN
# LateAircraftDelay     NaN     NaN

# %%
#Total count of records of the years 1989 and 1999
#Over 10 Million records are available in the datasets
Data1989.shape[0] + Data1999.shape[0]
# Out:
# 10569084

# %%
#Concatenate the null values counts of each columns/attributes for better understanding 
IsNull= pd.concat([Data1989.isnull().sum(),Data1999.isna().sum()], axis=1)
#Rename the column names [0,1] with the years [1989,1999]
IsNull.columns=['1989 GC','1999 GC']

# %%
IsNull
# Out:
#                    1989 GC  1999 GC
# Year                     0        0
# Month                    0        0
# DayofMonth               0        0
# DayOfWeek                0        0
# DepTime              74165   154311
# CRSDepTime               0        0
# ArrTime              89004   167866
# CRSArrTime               0        0
# UniqueCarrier            0        0
# FlightNum                0        0
# TailNum            5041200        0
# ActualElapsedTime    89004   167866
# CRSElapsedTime           0     8992
# AirTime            5041200   167866
# ArrDelay             89004   167866
# DepDelay             74165   154311
# Origin                   0        0
# Dest                     0        0
# Distance             26988        0
# TaxiIn             5041200        0
# TaxiOut            5041200        0
# Cancelled                0        0
# CancellationCode   5041200  5527884
# Diverted                 0        0
# CarrierDelay       5041200  5527884
# WeatherDelay       5041200  5527884
# NASDelay           5041200  5527884
# SecurityDelay      5041200  5527884
# LateAircraftDelay  5041200  5527884
# AirPortName           1021        0
# region_name            510        0
# AirLines             79333        0

# %%
# Exploring the numbel of Null values in the features 
IsNull.loc[(IsNull['1989 GC']!=0) | (IsNull['1999 GC']!=0)]
# Out:
#                    1989 GC  1999 GC
# DepTime              74165   154311
# ArrTime              89004   167866
# TailNum            5041200        0
# ActualElapsedTime    89004   167866
# CRSElapsedTime           0     8992
# AirTime            5041200   167866
# ArrDelay             89004   167866
# DepDelay             74165   154311
# Distance             26988        0
# TaxiIn             5041200        0
# TaxiOut            5041200        0
# CancellationCode   5041200  5527884
# CarrierDelay       5041200  5527884
# WeatherDelay       5041200  5527884
# NASDelay           5041200  5527884
# SecurityDelay      5041200  5527884
# LateAircraftDelay  5041200  5527884
# AirPortName           1021        0
# region_name            510        0
# AirLines             79333        0

# %%
Data1989.shape,Data1999.shape
# Out:
# ((5041200, 32), (5527884, 32))

# %%
#Drop the columns that have many null values 
# The columns to drop are: ===> CancellationCode,CarrierDelay,WeatherDelay,NASDelay,SecurityDelay,LateAircraftDelay
# Drop columns from the dataframe of the year 1989
Data1989.drop(["CancellationCode","CarrierDelay","WeatherDelay","NASDelay","SecurityDelay",
               "LateAircraftDelay"], 
             axis='columns',
             inplace=True)

# %%
# Drop columns from the dataframe of the year 1999
Data1999.drop(["CancellationCode","CarrierDelay","WeatherDelay","NASDelay","SecurityDelay",
               "LateAircraftDelay"], 
             axis='columns',
             inplace=True)

# %%
# Concatenating the two dataframes 
dframes=[Data1989,Data1999]
CombinedData=pd.concat(dframes)

# %%
#Departure, Arrival  and on-time Status
CombinedData['FlightStatus'] = ['Cancelled' if pd.isna(x) else ('On Time' if x<=0  else 'Delayed') for x in CombinedData['ArrDelay']]
CombinedData['FlightStatus'] = ['Cancelled' if pd.isna(x) else ('On Time' if x<=0  else 'Delayed') for x in CombinedData['DepDelay']]

# %%
CombinedData.dtypes
# Out:
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DayOfWeek              int64
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier         object
# FlightNum              int64
# TailNum               object
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin                object
# Dest                  object
# Distance             float64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled              int64
# Diverted               int64
# AirPortName           object
# region_name           object
# AirLines              object
# FlightStatus          object
# dtype: object

# %% [markdown]
# ### Export dataframe to csv file to visualize in the Tableau Desktop

# %%
CombinedData.to_csv("FinalCombinedDataModified.csv",index=False)

# %%
Reload1999and1989=pd.read_csv("FinalCombinedDataModified.csv")
# Out:
# C:\Users\Weldat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
Reload1999and1989.head(3)
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  1989      1          23          1   1419.0        1230   1742.0
# 1  1989      1          24          2   1255.0        1230   1612.0
# 2  1989      1          25          3   1230.0        1230   1533.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... Dest  Distance  TaxiIn  TaxiOut  \
# 0        1552            UA        183  ...  HNL    2398.0     NaN      NaN
# 1        1552            UA        183  ...  HNL    2398.0     NaN      NaN
# 2        1552            UA        183  ...  HNL    2398.0     NaN      NaN
#
#    Cancelled  Diverted                          AirPortName region_name  \
# 0          0         0  San Francisco International Airport  California
# 1          0         0  San Francisco International Airport  California
# 2          0         0  San Francisco International Airport  California
#
#                 AirLines  FlightStatus
# 0  United Air Lines Inc.       Delayed
# 1  United Air Lines Inc.       Delayed
# 2  United Air Lines Inc.       On Time
#
# [3 rows x 27 columns]

# %%
Reload1999and1989.dtypes
# Out:
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DayOfWeek              int64
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier         object
# FlightNum              int64
# TailNum               object
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin                object
# Dest                  object
# Distance             float64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled              int64
# Diverted               int64
# AirPortName           object
# region_name           object
# AirLines              object
# FlightStatus          object
# dtype: object

# %% [markdown]
# ## END of ETL Using Python Pandas
